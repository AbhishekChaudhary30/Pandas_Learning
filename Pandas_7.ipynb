# %%
import pandas as pd

# %%
df = pd.read_excel("Data_Train.xlsx")
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
# Extracting Day from Date of journey column
df["Journey_Day"] = pd.to_datetime(df.Date_of_Journey).dt.day
df.head()
# Out:
# C:\Users\ABHISHEK CHAUDHARY\AppData\Local\Temp\ipykernel_9452\2116334631.py:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["Journey_Day"] = pd.to_datetime(df.Date_of_Journey).dt.day
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# ...

# %%
# Extracting Month from Date of journey column
df["Journey_Month"] = pd.to_datetime(df.Date_of_Journey).dt.month
df.head()
# Out:
# C:\Users\ABHISHEK CHAUDHARY\AppData\Local\Temp\ipykernel_9452\4064314688.py:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["Journey_Month"] = pd.to_datetime(df.Date_of_Journey).dt.month
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# ...

# %%
#  Dropping Date_of_journey column
df.drop("Date_of_Journey", axis = 1, inplace = True)

# %%
df
# Out:
#            Airline    Source Destination                  Route Dep_Time  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    19:55
# 10679    Air India   Kolkata    Banglore              CCU → BLR    20:45
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    08:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    11:30
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    10:55
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price  Journey_Day  \
# ...

# %%
s1 = "2h 20m" # here s1 is duration of thime and we convert into minutes for extract time.
eval(s1.replace("h", "*60").replace(" ", "+").replace("m", "*1")) # first method.
# Out:
# 140

# %%
# Conversion of Duration column from hr & Minutes format to Minutes
# Second Method
df["Duration"]=df["Duration"].str.replace('h', '*60').str.replace(' ', '+').str.replace('m', '*1').apply(eval)

df['Duration'] = df['Duration'].astype(int)

# %%
# Extracting Hours from Dep_Time column
df["Dep_Hour"] = pd.to_datetime(df["Dep_Time"]).dt.hour
# Out:
# C:\Users\ABHISHEK CHAUDHARY\AppData\Local\Temp\ipykernel_9452\1196621961.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Dep_Hour"] = pd.to_datetime(df["Dep_Time"]).dt.hour

# %%
# Extracting Minutes from Dep_Time column
df["Dep_Min"] = pd.to_datetime(df["Dep_Time"]).dt.minute
# Out:
# C:\Users\ABHISHEK CHAUDHARY\AppData\Local\Temp\ipykernel_9452\1730398078.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Dep_Min"] = pd.to_datetime(df["Dep_Time"]).dt.minute

# %%
# Dropping Dep_Time column
df.drop("Dep_Time", axis =1, inplace= True)

# %%
df
# Out:
#            Airline    Source Destination                  Route  Arrival_Time  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
# ...            ...       ...         ...                    ...           ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR         22:25
# 10679    Air India   Kolkata    Banglore              CCU → BLR         23:20
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL         11:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL         14:10
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK         19:15
#
# ...

# %%
# 4. Feature Engineering on 'Arrival_Time' Column
# # Extracting Arrival_Hour from Arrival_Time column
df['Arrival_Hour'] = pd.to_datetime(df["Arrival_Time"]).dt.hour

# Extracting Arrival_Min from Arrival_Time column
df["Arrival_Min"] = pd.to_datetime(df["Arrival_Time"]).dt.minute

# Dropping Arrival_Time column
df.drop("Arrival_Time", axis =1, inplace=True)
# Out:
# C:\Users\ABHISHEK CHAUDHARY\AppData\Local\Temp\ipykernel_9452\2124843028.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Arrival_Hour'] = pd.to_datetime(df["Arrival_Time"]).dt.hour
# C:\Users\ABHISHEK CHAUDHARY\AppData\Local\Temp\ipykernel_9452\2124843028.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Arrival_Min"] = pd.to_datetime(df["Arrival_Time"]).dt.minute

# %%
df
# Out:
#            Airline    Source Destination                  Route  Duration  \
# 0           IndiGo  Banglore   New Delhi              BLR → DEL       170
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR       445
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      1140
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR       325
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL       285
# ...            ...       ...         ...                    ...       ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR       150
# 10679    Air India   Kolkata    Banglore              CCU → BLR       155
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL       180
# 10681      Vistara  Banglore   New Delhi              BLR → DEL       160
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK       500
#
#       Total_Stops Additional_Info  Price  Journey_Day  Journey_Month  \
# ...

# %%
df["Destination"].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
# Replacing "New Delhi" as 'Delhi' in Destination Column
df["Destination"]= df["Destination"].replace("New Delhi", "Delhi")

# %%
df["Additional_Info"].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
# In the column "Additional Info" "No Info" and "No info" are same so replacing it by "No Info"
df['Additional_Info'] = df['Additional_Info'].replace("No info", "No Info")

# %%
df
# Out:
#            Airline    Source Destination                  Route  Duration  \
# 0           IndiGo  Banglore       Delhi              BLR → DEL       170
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR       445
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      1140
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR       325
# 4           IndiGo  Banglore       Delhi        BLR → NAG → DEL       285
# ...            ...       ...         ...                    ...       ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR       150
# 10679    Air India   Kolkata    Banglore              CCU → BLR       155
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL       180
# 10681      Vistara  Banglore       Delhi              BLR → DEL       160
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK       500
#
#       Total_Stops Additional_Info  Price  Journey_Day  Journey_Month  \
# ...

# %%
# Data Integrity Check -- Duplicate value
df.duplicated().sum() # This will check duplicate data for all columns.
# Out:
# 222

# %%
df.shape
# Out:
# (10683, 14)

# %%
df.drop_duplicates(keep = 'last', inplace = True)

# %%
df.shape
# Out:
# (10461, 14)

# %%
# Finding what percentage of data is missing from the dataset
df.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Route              1
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# Journey_Day        0
# Journey_Month      0
# Dep_Hour           0
# Dep_Min            0
# Arrival_Hour       0
# Arrival_Min        0
# dtype: int64

# %%
df.dropna(inplace=True) # here all null values are dropped by this syntax.

# %%
df.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Route              0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# Journey_Day        0
# Journey_Month      0
# Dep_Hour           0
# Dep_Min            0
# Arrival_Hour       0
# Arrival_Min        0
# dtype: int64

# %%
df["Total_Stops"].value_counts()
# Out:
# Total_Stops
# 1 stop      5625
# non-stop    3473
# 2 stops     1318
# 3 stops       43
# 4 stops        1
# Name: count, dtype: int64

# %%
df["Total_Stops"] = df['Total_Stops'].fillna(df["Total_Stops"].mode()[0])

# %%
df['Total_Stops']=df['Total_Stops'].map({"non-stop":0,"1 stop":1,"2 stops":2,"3 stops": 3,"4 stops":4})

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  Duration  \
# 0       IndiGo  Banglore       Delhi              BLR → DEL       170
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR       445
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      1140
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR       325
# 4       IndiGo  Banglore       Delhi        BLR → NAG → DEL       285
#
#    Total_Stops Additional_Info  Price  Journey_Day  Journey_Month  Dep_Hour  \
# 0            0         No Info   3897           24              3        22
# 1            2         No Info   7662            1              5         5
# 2            2         No Info  13882            9              6         9
# 3            1         No Info   6218           12              5        18
# 4            1         No Info  13302            1              3        16
#
#    Dep_Min  Arrival_Hour  Arrival_Min
# 0       20             1           10
# ...
